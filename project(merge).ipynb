# %%
#Python GUI -Profile Personal Detail (main)
from tkinter import *
from tkinter.ttk import Combobox
from tkinter.ttk import *
from tkinter import messagebox
import tkinter.messagebox as MessageBox
import mysql.connector as mysql
import tkinter as tk
from PIL import ImageTk, Image
import MySQLdb


class EmiCalculator:
    
    def __init__(self,window1):
        
        self.CPRR=Button(window1,text="Profile Personal Details",command=self.Profile_Personal_Detail)
        self.CPRR.place(x=20,y=60)
        self.CPRR=Button(window1,text="login",command=self.login)
        self.CPRR.place(x=20,y=30)
        self.CPR=Button(window1,text="Profile Account Detail",command=self.profile_acc_detail)
        self.CPR.place(x=20,y=90)



    def updateData(self):
        self.uid=self.uid.get()
        self.uname=self.uname.get()
        self.password=self.password.get()
        self.securityQues=self.securityQues.get()
        self.securityans=self.securityans.get()
        
        try:

            
            db=MySQLdb.connect('localhost','root','root','userprofile')
            cursor=db.cursor()
            sqlquery="update profile_acc_detail set uname=%s , password=%s,securityQues=%s,securityans=%s where uid=%s"
            cursor.execute(sqlquery,(self.uname,self.password,self.securityQues,self.securityans,self.uid))
            db.commit()
            print("Record update successfully.....!")
            messagebox.showinfo("Success","Record has been update succesfully.")
            
        except MySQLdb.Error as error:
            db.rollback()            
            print('Fail to insert the record',error)
    
    
    def insertData(self):
        self.uid=self.uid.get()
        self.uname=self.uname.get()
        self.password=self.password.get()
        self.securityQues=self.securityQues.get()
        self.securityans=self.securityans.get()
        
        try:
            db=MySQLdb.connect('localhost','root','root','userprofile')
            cursor=db.cursor()
            sqlquery='insert into profile_acc_detail(uid,uname,password,securityQues,securityans) values(%s,%s,%s,%s,%s)'
    
            res = cursor.execute(sqlquery,(self.uid,self.uname,self.password,self.securityQues,self.securityans))
            db.commit()
            print('record has been saved successfully ')
            messagebox.showinfo("Success","Record has been saved succesfully.")
    
        except MySQLdb.Error as error:
            print('Fail to insert the record',error)


    def profile_acc_detail(self):
        window=tk.Toplevel()
        window.title(" Profile_Account_Details")
        window.geometry("700x650+40+40")        
        
        self.lbl=Label(window,text="Profile Account Detail",font=("arial",20,'bold'))
        self.lbl.place(x=110,y=20)

        self.lbl1=Label(window,text="User ID",font=("arial",12))
        self.lbl1.place(x=20,y=100)
        self.uid=Entry(window)
        self.uid.place(x=180,y=100)

        self.lbl2=Label(window,text="Username",font=('ariel',12))
        self.lbl2.place(x=20,y=150)
        self.uname=Entry(window)
        self.uname.place(x=180,y=150)

        self.lbl3=Label(window,text="Password",font=("arial",12))
        self.lbl3.place(x=20,y=200)
        self.password=Entry(window,show="*")
        self.password.place(x=180,y=200)
        
        path = "C:\\emp.jpg"
        self.img = ImageTk.PhotoImage(Image.open(path))
        self.panel = tk.Label(window, image = self.img)
        self.panel.place(x=490,y=100)

        self.lbl4=Label(window,text="Security Question",font=('ariel',12))
        self.lbl4.place(x=20,y=250)
        self.course=('What is your pet name','What is your favourate colos','What is your First school name','What is your First school name','What is your Hobby')
        self.securityQues=Combobox(window,values=self.course)
        self.securityQues.place(x=180,y=250,width=250)

        self.lbl5=Label(window,text="Security Answer",font=('ariel',12))
        self.lbl5.place(x=20,y=300)
        self.securityans=Entry(window)
        self.securityans.place(x=180,y=300)

        self.btn=Button(window,text="Update",command=self.updateData)
        self.btn.place(x=180,y=350)
        self.btn=Button(window,text="Save",command=self.insertData)
        self.btn.place(x=300,y=350)
                
        dbcon = MySQLdb.connect('localhost','root','root','userprofile')
        cursorobj = dbcon.cursor()
        cursorobj.execute("select * from profile_acc_detail where uname=%s",(self.username,))
        #print(self.username)
        data = cursorobj.fetchall()
        #print(data)     
        count = 1
        if count > 0:
                for row in data:
        
                    self.uid.insert(END,(row[0]))
                    self.uname.insert(END,row[1])
                    self.password.insert(END,row[2])
                    self.securityQues.insert(END,row[3])
                    self.securityans.insert(END,row[4])

        else:
                messagebox.showinfo("record not found")
        dbcon.close()

        window.mainloop
        
    def insertData2(self):
     
        self.username=self.username.get()
        self.password=self.password.get()
       
        
        try:
            db=MySQLdb.connect('localhost','root','root','userprofile')
            cursor=db.cursor()
            sqlquery='insert into login(username,password) values(%s,%s)'
    
            res = cursor.execute(sqlquery,(self.username,self.password))
            db.commit()
            print('record has been saved successfully ')
            messagebox.showinfo("Success","Record has been saved succesfully.")
    
        except MySQLdb.Error as error:
            print('Fail to insert the record',error)


    def login(self):
        window=Tk()
        window.title(" Profile_Account_Details")
        window.geometry("700x650+40+40")        

        
        self.lbl=Label(window,text="Profile Account Detail",font=("arial",20,'bold'))
        self.lbl.place(x=110,y=20)

        self.lbl2=Label(window,text="Username",font=('ariel',12))
        self.lbl2.place(x=20,y=150)
        self.username=Entry(window)
        self.username.place(x=180,y=150)

        self.lbl3=Label(window,text="Password",font=("arial",12))
        self.lbl3.place(x=20,y=200)
        self.password=Entry(window,show="*")
        self.password.place(x=180,y=200)


        self.btn=Button(window,text="Submit",command=self.insertData2)
        self.btn.place(x=300,y=350)
        window.mainloop
    

    
    def updateData1(self):
        self.uid=self.uid.get()
        self.name=self.name.get()
        self.Date_of_birth=(self.Date_of_birth1.get() + " " + self.Date_of_birth2.get()+ " " + self.Date_of_birth3.get())
        self.Address=self.Address1.get() + "," + self.Address2.get()+ "," + self.Address3.get()+ "," + self.Address4.get()
        self.phone=self.phone.get()
        self.mobile=self.mobile.get()
        self.gmail=self.gmail.get()

        try:

            print("Record update successfully.....!")
            db=MySQLdb.connect('localhost','root','root','userprofile')
            cursor=db.cursor()
            sqlquery="update Profile_Personal_Detail set name=%s ,Date_of_birth=%s,Address=%s, phone=%s,mobile=%s,gmail=%s where uid=%s"
            cursor.execute(sqlquery,(self.name,self.Date_of_birth,self.Address,self.phone,self.mobile,self.gmail,self.uid))
            db.commit()
            print('record has been update successfully ')
            messagebox.showinfo("Success","Record has been update succesfully.")
            
        except MySQLdb.Error as error:
            db.rollback()            
            print('Fail to insert the record',error)
    def insertData1(self):
        self.uid=self.uid1.get()
        self.name=self.name.get()
        self.Date_of_birth=(self.Date_of_birth1.get() + " " + self.Date_of_birth2.get()+ " " + self.Date_of_birth3.get())
        self.Address=self.Address1.get() + "," + self.Address2.get()+ "," + self.Address3.get()+ "," + self.Address4.get()
        self.phone=self.phone.get()
        self.mobile=self.mobile.get()
        self.gmail=self.gmail.get()
        #print(self.uid,self.name,self.phone,self.Address)
        try:
            db=MySQLdb.connect('localhost','root','root','userprofile')
            cursor=db.cursor()
            sqlquery='insert into Profile_Personal_Detail(uid,name,Date_of_birth,Address,phone,mobile,gmail) values(%s,%s,%s,%s,%s,%s,%s)'
    
            res = cursor.execute(sqlquery,(self.uid,self.name,self.Date_of_birth,self.Address,self.phone,self.mobile,self.gmail))
            db.commit()
            print('record has been saved successfully ')
            messagebox.showinfo("Success","Record has been saved succesfully.")
    
        except MySQLdb.Error as error:

            print('Fail to insert the record',error)

    def Profile_Personal_Detail(self):
        
        window=tk.Toplevel()
        window.title(" Profile_Personal_Details")
        window.geometry("700x650+40+40")        
        self.lbl=Label(window,text="Profile Personal Detail",font=("arial",20,'bold'))
        self.lbl.place(x=110,y=20)

        self.lbl1=Label(window,text="User ID",font=("arial",12))
        self.lbl1.place(x=20,y=100)
        self.uid=Entry(window)
        self.uid.place(x=180,y=100)

        self.lbl2=Label(window,text="Name",font=('ariel',12))
        self.lbl2.place(x=20,y=150)
        self.name=Entry(window)
        self.name.place(x=180,y=150)
                
        path = "C:\\employ.jpg"
        self.img = ImageTk.PhotoImage(Image.open(path))
        self.panel = tk.Label(window, image = self.img)
        self.panel.place(x=480,y=20)

        self.lbl3=Label(window,text="Date Of Birth",font=("arial",12))
        self.lbl3.place(x=20,y=200)
        self.course=[]
        for i in range(1,31):
            self.course.append(i)
        self.Date_of_birth1=Combobox(window,values=self.course)
        self.Date_of_birth1.place(x=180,y=200,width=50)

        self.course2 = (' January',  
                                  ' February', 
                                  ' March', 
                                  ' April', 
                                  ' May', 
                                  ' June', 
                                  ' July', 
                                  ' August', 
                                  ' September', 
                                  ' October', 
                                  ' November', 
                                  ' December') 

        self.Date_of_birth2=Combobox(window,values=self.course2)
        self.Date_of_birth2.place(x=250,y=200)

        self.course1=[]
        for i in range(1950,2021):
            self.course1.append(i)

        self.Date_of_birth3=Combobox(window,values=self.course1)
        self.Date_of_birth3.place(x=415,y=200)
        
        self.lbl4=Label(window,text="Address",font=('ariel',12))
        self.lbl4.place(x=20,y=250)

        self.lbl4=Label(window,text="Street Address",font=('ariel',10))
        self.lbl4.place(x=190,y=275)
        self.Address1=Entry(window)
        self.Address1.place(x=180,y=250)

        self.lbl41=Label(window,text="Pincode",font=('ariel',10))
        self.lbl41.place(x=190,y=325)
        self.Address2=Entry(window)
        self.Address2.place(x=180,y=300)

        self.lbl42=Label(window,text="State",font=('ariel',10))
        self.lbl42.place(x=190,y=375)
        self.Address3=Entry(window)
        self.Address3.place(x=180,y=350)

        self.lbl43=Label(window,text="Country",font=('ariel',10))
        self.lbl43.place(x=450,y=325)
        self.countries = ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla', 'Antigua And Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia And Herzegovina', 'Botswana', 'Bouvet Island', 'Brazil', 'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands', 'Chad', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', 'Croatia', 'Curacao', 'Cyprus', 'Czech Republic', 'Democratic Republic Of The Congo', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'East Timor', 'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Estonia', 'Ethiopia', 'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Guiana', 'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle Of Man', 'Israel', 'Italy', 'Ivory Coast', 'Jamaica', 'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kosovo', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Libyan Arab Jamahiriya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao', 'Macau', 'Macedonia', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Martinique', 'Mauritania', 'Mauritius', 'Mexico', 'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nepal', 'Netherlands', 'Netherlands Antilles', 'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Norway', 'Oman', 'Pakistan', 'Palestine', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Reunion', 'Romania', 'Russia', 'Russian Federation', 'Rwanda', 'Saint Kitts And Nevis', 'Saint Lucia', 'Saint Martin', 'Saint Pierre And Miquelon', 'Saint Vincent And The Grenadines', 'Samoa', 'San Marino', 'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Slovakia', 'Slovenia', 'Somalia', 'South Africa', 'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan', 'Suriname', 'Swaziland', 'Sweden', 'Switzerland', 'Taiwan', 'Tajikistan', 'Tanzania', 'Tanzania, United Republic Of', 'Thailand', 'Togo', 'Tonga', 'Trinidad And Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Turks And Caicos Islands', 'U.S. Virgin Islands', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United States', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam', 'Wallis And Futuna', 'Yemen', 'Zambia', 'Zimbabwe']  
        self.Address4=Combobox(window,values=self.countries)
        self.Address4.place(x=400,y=300,width=150)

        self.lbl5=Label(window,text="Phone",font=('ariel',12))
        self.lbl5.place(x=20,y=450)
        self.phone=Entry(window)
        self.phone.place(x=180,y=450)

        self.lbl6=Label(window,text="Mobile",font=('ariel',12))
        self.lbl6.place(x=20,y=500)
        self.mobile=Entry(window)
        self.mobile.place(x=180,y=500)
        
        self.lbl7=Label(window,text='gmail',font=('ariel',12))
        self.lbl7.place(x=20,y=550)
        self.gmail=Entry(window)
        self.gmail.place(x=180,y=550)

        self.btn=Button(window,text="Update",command=self.updateData1)
        self.btn.place(x=180,y=600)
        self.btn=Button(window,text="Save",command=self.insertData1)
        self.btn.place(x=300,y=600)
        
                
        dbcon = MySQLdb.connect('localhost','root','root','userprofile')
        cursorobj = dbcon.cursor()
        cursorobj.execute("select * from Profile_Personal_Detail where name=%s",(self.username,))
        #print(self.username)
        data = cursorobj.fetchall()
        #print(data)
        
        count = 1
        if count > 0:
                for row in data:

                    self.uid.insert(END,(row[0]))
                    self.name.insert(END,row[1])
                    row1=row[2].split()
                    #print(row1)
                    self.Date_of_birth1.insert(END,row1[0])
                    self.Date_of_birth2.insert(END,row1[1])
                    self.Date_of_birth3.insert(END,row1[2])
                    row2=row[3].split(',')
                    self.Address1.insert(END,row2[0])
                    self.Address2.insert(END,row2[1])
                    self.Address3.insert(END,row2[2])
                    self.Address4.insert(END,row2[3])
                    self.phone.insert(END,row[4])
                    self.mobile.insert(END,row[5])
                    self.gmail.insert(END,row[6])


        else:
                messagebox.showinfo("record not found")
        dbcon.close()

        window.mainloop

window1=Tk()
window1.geometry("700x650+40+40")
window1.title("User Profile")
obj =EmiCalculator(window1)
window1.mainloop()

# %%
n=int(input())
count=0
arr=list(map(int,input().split()))[:n]
for i in range(1,n):
    print(i)
    if arr[i]%i==0:
        
        print(arr[i])
        count+=1
        print(count)
    else:
        continue
    if count==3:
        print("YES")
    else:
        print("NO")
# Out:
# 3
# 4 5 6
# 1
# 5
# 1
# NO
# 2
# 6
# 2
# NO
