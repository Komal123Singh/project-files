# %%
from tkinter import *
from PIL import ImageTk, Image 

class AlphaSystem:
    
    def __init__(self,win):
        self.lbl1=Label(win,text='Employee ID')
        self.lbl2=Label(win,text='Full Name')
        self.lbl3=Label(win,text= 'Date of Birth')
        self.lbl4=Label(win,text= 'Current Address')
        self.lbl5=Label(win,text= 'Phone Number')
        self.lbl6=Label(win,text= 'Mobile Number')
        self.lbl7=Label(win,text= 'E-Mail ID')
        
        
        self.label = Label(win, text="*****EMPLOYEE PERSONAL DETAILS*****",font=("Algerian",20,'bold'))
        self.label.pack()
        
        
        self.t1=Entry(win,bd=4,font=('arial',15))
        self.t2=Entry(win,bd=4,font=('arial',15))
        self.t3=Entry(win,bd=4,font=('arial',15))
        self.t4=Entry(win,bd=4,font=('arial',15))
        self.t5=Entry(win,bd=4,font=('arial',15))
        self.t6=Entry(win,bd=4,font=('arial',15))
        self.t7=Entry(win,bd=4,font=('arial',15))
        
        
        self.lbl1.place(x=100,y=50)
        self.t1.place(x=200,y=50)
        
        self.lbl2.place(x=100,y=100)
        self.t2.place(x=200,y=100)
     
        self.lbl3.place(x=100,y=150)
        self.t3.place(x=200,y=150)
        
        self.lbl4.place(x=100,y=200)
        self.t4.place(x=200,y=200)
        
        self.lbl5.place(x=100,y=250)
        self.t5.place(x=200,y=250)
        
        self.lbl6.place(x=100,y=300)
        self.t6.place(x=200,y=300)
        
        self.lbl7.place(x=100,y=350)
        self.t7.place(x=200,y=350)
        
        self.update_button = Button(win, text="Update",command=self.update,width=10,height=1)
        self.update_button.pack()
        self.update_button.place(x=100,y=400)
        self.update_button.place(x=200,y=400)

        self.save_button = Button(win, text="Save",command=self.save,width=10,height=1)
        self.save_button.pack()
        self.save_button.place(x=300,y=400)
        self.save_button.place(x=350,y=400)
        
    def update(self):
        self.update.delete(0,'end')
        self.update.insert(END,str(database))

        
    def save(self):
        self.save.delete(0,'end')
        self.save.insert(END,str(database))


window =Tk()
window.configure(bg='lightgray')

bg=ImageTk.PhotoImage(file="C:\\Users\\user\\Documents\\Acentum\\alphainventory\\login.jpeg")
bg_image=Label(window,image=bg,width=280,height=350)
bg_image.pack()
bg_image.place(x=470,y=50)

AlphaSystem(window)
window.title('EMPLOYEE PERSONAL DETAILS...!!!')
window.geometry('800x500+350+100')
window.mainloop()
