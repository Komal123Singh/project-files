# %%
#Python GUI - window

from tkinter import *

window=Tk()
window.geometry("500x100+300+200")
window.mainloop()

# %%
#Python GUI - window with title

from tkinter import *

window=Tk()
window.title('My First window in Python')
window.geometry("500x100+300+200")
window.mainloop()

# %%
#Python GUI - Button

from tkinter import *

window=Tk()
window.title('My First window in Python')

btn=Button(window,text="Click Me...!",bg="yellow",fg="red",font=("algerian",20,'bold'))
btn.place(x=150,y=100)

window.geometry("500x300+300+200")
window.mainloop()

# %%
#Python GUI - Label (display text on screen)
from tkinter import *
window=Tk()
window.title('My First window in Python')

lbl=Label(window,text="Welcome to Python GUI.",bg="navy",fg="white",font=("arial",20,'bold'))
lbl.place(x=110,y=20)

btn=Button(window,text="Click Me...!",bg="yellow",fg="red",font=("algerian",20,'bold'))
btn.place(x=150,y=100)

window.geometry("500x300+300+200")
window.mainloop()

# %%
#Python GUI - Entry (input single line text from user)
from tkinter import *
window=Tk()
window.title('My First window in Python')

lbl=Label(window,text="Welcome to Python GUI.",bg="navy",fg="white",font=("arial",20,'bold'))
lbl.place(x=110,y=20)

var=StringVar()
var.set("username here...")

lbl=Label(window,text="Enter username",fg="blue",font=("arial",14))
lbl.place(x=20,y=120)

txtfld=Entry(window,textvariable=var,bd=5)
txtfld.place(x=180,y=120)

btn=Button(window,text="Click Me...!",bg="yellow",fg="red",font=("algerian",15,'bold'))
btn.place(x=150,y=250)

window.geometry("500x300+300+200")
window.mainloop()

# %%
#Python GUI - Entry (input single line text from user in "password")
window=Tk()
window.title('My First window in Python')

lbl=Label(window,text="Welcome to Python GUI.",bg="navy",fg="white",font=("arial",20,'bold'))
lbl.place(x=110,y=20)


lbl=Label(window,text="Enter password",fg="blue",font=("arial",14))
lbl.place(x=20,y=120)

txtfld=Entry(window,bd=5,show="@",bg="yellow")
txtfld.place(x=180,y=120)

btn=Button(window,text="Click Me...!",bg="yellow",fg="red",font=("algerian",15,'bold'))
btn.place(x=150,y=250)

window.geometry("500x300+300+200")
window.mainloop()

# %%
#Python GUI - RadioButton widget
from tkinter import *

window=Tk()
window.title('My First window in Python')

var=IntVar()
var.set(2)

r1=Radiobutton(window,text="Male", variable=var, value=1)
r2=Radiobutton(window,text="Female",variable=var, value=2)

r1.place(x=100,y=50)
r2.place(x=180,y=50)

window.geometry("500x300+300+200")
window.mainloop()

# %%
#Python GUI - Checkbutton widget
from tkinter import *

window=Tk()
window.title('My First window in Python')

var1=IntVar()
var2=IntVar()

c1=Checkbutton(window,text="C", variable=var1)
c2=Checkbutton(window,text="C++",variable=var2)

c1.place(x=100,y=50)
c2.place(x=180,y=50)

window.geometry("500x300+300+200")
window.mainloop()

# %%
#Python GUI - Combobox widget
from tkinter import *
from tkinter.ttk import Combobox

window=Tk()
window.title('My First window in Python')

courses=("C","C++","Python","Django")

var=StringVar()
var.set("select")

cb=Combobox(window,values=courses,textvariable=var)

cb.place(x=100,y=50)

window.geometry("500x300+300+200")
window.mainloop()

# %%
#Python GUI - Listbox widget
from tkinter import *

window=Tk()
window.title('My First window in Python')


fruit=("Apple","Banana","Grapes","Papaya","Gauava","PineApple","Mango")

lbx=Listbox(window,height=5,selectmode='multiple')
for num in fruit:
    lbx.insert(END,num)

lbx.place(x=100,y=50)

window.geometry("500x300+300+200")
window.mainloop()

# %%
#Python GUI - Button-event handling

from tkinter import *

def myfun():
    print("Welcome to Python GUI")


window=Tk()
window.title('My First window in Python')

btn=Button(window,text="Click Me...!",bg="yellow",fg="red",font=("algerian",20,'bold'),command=myfun)
btn.place(x=150,y=100)

window.geometry("500x300+300+200")
window.mainloop()
# Out:
# Welcome to Python GUI
# Welcome to Python GUI

# %%
#Python GUI Calculator
from tkinter import *

class MyCalculator:
    def __init__(self,win):
        self.lbl1=Label(win,text="Enter 1st no.")
        self.lbl2=Label(win,text="Enter 2nd no.")
        self.lbl3=Label(win,text="Result")
        
        self.t1=Entry(win,bd=4)
        self.t2=Entry(win,bd=4)
        self.t3=Entry(win,bd=4,bg="yellow",fg="red",font=("arial",15))
        
        self.btnADD=Button(win,text="+",bg='cyan',command=self.add)
        self.btnMultiply=Button(win,text="*",bg='cyan',command=self.product)
        
        self.lbl.place(x=110,y=20)
        self.lbl1.place(x=100,y=50)
        self.t1.place(x=200,y=50)
        
        self.lbl2.place(x=100,y=100)
        self.t2.place(x=200,y=100)
        
        self.btnADD.place(x=200,y=150)
        self.btnMultiply.place(x=300,y=150)
        
        self.lbl3.place(x=100,y=200)
        self.t3.place(x=200,y=200)
        
    def add(self):
        self.t3.delete(0,'end')
        num1 = int(self.t1.get())
        num2 = int(self.t2.get())
        result = num1+num2
        self.t3.insert(END,str(result))
        
    def product(self):
        self.t3.delete(0,'end')
        num1 = int(self.t1.get())
        num2 = int(self.t2.get())
        result = num1*num2
        self.t3.insert(END,str(result))

window = Tk()
MyCalculator(window)
window.title("My Python GUI Calculator...!")
window.geometry("500x300+300+200")
window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-3a578c86079c> in <module>()
#      43
#      44 window = Tk()
# ---> 45 MyCalculator(window)
#      46 window.title("My Python GUI Calculator...!")
#      47 window.geometry("500x300+300+200")
#
# <ipython-input-3-3a578c86079c> in __init__(self, win)
#      15         self.btnMultiply=Button(win,text="*",bg='cyan',command=self.product)
#      16
# ---> 17         self.lbl.place(x=110,y=20)
#      18         self.lbl1.place(x=100,y=50)
#      19         self.t1.place(x=200,y=50)
#
# AttributeError: 'MyCalculator' object has no attribute 'lbl'

# %%
class Calci:
    def __init__(self,win):
        self.lb1=Label(win,text="Enter 1st No ")
        self.lb2=Label(win,text="Enter 2nd No ")
        self.lb3=Label(win,text="Result ",font=("Times New Roman",15,"bold"))
        self.lbl=Label(window,text="Python Calculator.",bg="navy",fg="white",font=("arial",20,'bold'))
        
        
        
        self.t1=Entry(win,bd=4)
        self.t2=Entry(win,bd=4)
        self.t3=Entry(win,bd=4,bg="blue",fg="pink",font=('arial',10))
        
        self.btn0=Button(win,text="0",bg="grey",bd=4,font=('arial',10,'bold'))
        self.btn1=Button(win,text="1",bg="grey",bd=4,font=('arial',10,'bold'))
        self.btn2=Button(win,text="2",bg="grey",bd=4,font=('arial',10,'bold'))
        self.btn3=Button(win,text="3",bg="grey" ,bd=4,font=('arial',10,'bold'))
        self.btn4=Button(win,text="4",bg="grey",bd=4,font=('arial',10,'bold'))
        self.btn5=Button(win,text="5",bg="grey",bd=4,font=('arial',10,'bold'))
        self.btn6=Button(win,text="6",bg="grey",bd=4,font=('arial',10,'bold'))
        self.btn7=Button(win,text="7",bg="grey",bd=4,font=('arial',10,'bold'))
        self.btn8=Button(win,text="8",bg="grey",bd=4,font=('arial',10,'bold'))
        self.btn9=Button(win,text="9",bg="grey",bd=4,font=('arial',10,'bold'))
        self.btnAdd=Button(win,text="+",bg="grey",bd=4,font=('arial',10,'bold'))
        self.btnSub=Button(win,text="-",bg="grey",bd=4,font=('arial',10,'bold'))
        self.btnMul=Button(win,text="*",bg="grey",bd=4,font=('arial',10,'bold'))
        self.btnDiv=Button(win,text="/",bg="grey",bd=4,font=('arial',10,'bold'))
        self.btnClear=Button(win,text="C",bg="grey",bd=4,font=('arial',10,'bold'))
        self.btnRes=Button(win,text="=",bg="grey",bd=4,font=('arial',10,'bold'))
        
        self.lbl.place(x=200,y=2)
        self.lb1.place(x=30,y=50)
        self.t1.place(x=130,y=50)
        
        self.lb2.place(x=30,y=100)
        self.t2.place(x=130,y=100)
        
        self.lb3.place(x=30,y=150)
        self.t3.place(x=125,y=150)
        
        self.btn0.place(x=400,y=50)
        self.btn1.place(x=400,y=50)
        self.btn2.place(x=400,y=50)
        self.btn3.place(x=400,y=50)
        self.btn4.place(x=400,y=50)
        self.btn5.place(x=400,y=50)
        self.btn6.place(x=400,y=50)
        self.btn7.place(x=400,y=50)
        self.btn8.place(x=400,y=50)
        self.btn9.place(x=400,y=50)
        self.btnAdd.place(x=400,y=50)
        self.btnSub.place(x=400,y=50)
        self.btnMul0.place(x=400,y=50)
        self.btnDiv.place(x=400,y=50)
        self.btn0.place(x=400,y=50)
        self.btn0.place(x=400,y=50)
        self.btn0.place(x=400,y=50)
window=Tk()
Calci(window)
window.title("My Calculator")
window.geometry("600x600+400+300")
window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-787e30612777> in <module>()
#      57         self.btn0.place(x=400,y=50)
#      58 window=Tk()
# ---> 59 Calci(window)
#      60 window.title("My Calculator")
#      61 window.geometry("600x600+400+300")
#
# <ipython-input-4-787e30612777> in __init__(self, win)
#      51         self.btnAdd.place(x=400,y=50)
#      52         self.btnSub.place(x=400,y=50)
# ---> 53         self.btnMul0.place(x=400,y=50)
#      54         self.btnDiv.place(x=400,y=50)
#      55         self.btn0.place(x=400,y=50)
#
# AttributeError: 'Calci' object has no attribute 'btnMul0'
